# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from sklearn import metrics

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
# Load the dataset
df=pd.read_csv('portals.csv')

# %%
df
# Out:
#                                                   name  \
# 0                                            a2gov_org
# 1                             acikveri-sahinbey-bel-tr
# 2                                     africa_open_data
# 3                              ajuntament-de-tarragona
# 4                                ajuntament-de-terassa
# ..                                                 ...
# 589                                state_of_washington
# 590                                state_of_washington
# 591  portal-de-dados-abertos-da-camara-legislativa-...
# 592                                            stat-uz
# 593                                        data-gov-uz
#
#                                                  title  \
# 0                                  Ann Arbor, Michigan
# 1                      Açık Veri Portali - Test Yayını
# 2                                     Africa Open Data
# 3                                  Open Data Tarragona
# ...

# %%
''' Data Preprocessing'''
# Check for missing values in the data using pandas isnull()
df.isnull()
# Out:
#       name  title    url  author  publisher  issued  publisher_classification  \
# 0    False  False  False   False      False    True                      True
# 1    False  False  False   False      False   False                     False
# 2    False  False  False   False      False    True                      True
# 3    False  False  False   False      False    True                     False
# 4    False  False  False   False      False    True                     False
# ..     ...    ...    ...     ...        ...     ...                       ...
# 589  False  False  False   False      False    True                     False
# 590  False  False  False   False      False    True                     False
# 591  False  False  False    True       True    True                     False
# 592  False  False  False   False      False   False                     False
# 593  False  False  False   False      False   False                     False
#
# ...

# %%
# describe() : returns the statistical summary of dataframe or series.
df.describe()
# Out:
#                        name       title                            url  \
# count                   594         594                            594
# unique                  590         588                            590
# top     state_of_washington  Washington  http://opendata.terrassa.cat/
# freq                      4           4                              2
#
#                                 author                       publisher  \
# count                              529                             533
# unique                             487                             496
# top     African Development Bank Group  African Development Bank Group
# freq                                21                              22
#
#             issued publisher_classification  \
# count           92                      212
# unique          82                       11
# top     30/06/2015               Government
# freq             2                      177
#
# ...

# %%
print(df.size) # counts no. of ele along the given axis
print(df.shape) # gives the number of elements in each dimension of an array
print(df.ndim) # return the number of dimensions of an array.
# Out:
# 12474
# (594, 21)
# 2

# %%
df.dtypes # data types of each col
# Out:
# name                        object
# title                       object
# url                         object
# author                      object
# publisher                   object
# issued                      object
# publisher_classification    object
# description                 object
# tags                        object
# license_id                  object
# license_url                 object
# place                       object
# location                    object
# country                     object
# language                    object
# status                      object
# metadatacreated             object
# generator                   object
# api_endpoint                object
# api_type                    object
# full_metadata_download      object
# dtype: object

# %%
dummies=pd.get_dummies(df.author) # return dummy variable colums
merged=pd.concat([df,dummies],axis='columns') # to concatenate dummy columns into df

# %%
merged.drop(['author'],axis='columns') # drop column author from dataset
# Out:
#                                                   name  \
# 0                                            a2gov_org
# 1                             acikveri-sahinbey-bel-tr
# 2                                     africa_open_data
# 3                              ajuntament-de-tarragona
# 4                                ajuntament-de-terassa
# ..                                                 ...
# 589                                state_of_washington
# 590                                state_of_washington
# 591  portal-de-dados-abertos-da-camara-legislativa-...
# 592                                            stat-uz
# 593                                        data-gov-uz
#
#                                                  title  \
# 0                                  Ann Arbor, Michigan
# 1                      Açık Veri Portali - Test Yayını
# 2                                     Africa Open Data
# 3                                  Open Data Tarragona
# ...
